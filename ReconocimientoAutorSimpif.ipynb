# %%
# Eliminar el archivo paintings.csv
# !rm paintings.csv

# Eliminar la carpeta wikiart_images y su contenido
# !rm -r wikiart_images
# Out:
# rm: cannot remove 'wikiart_images': No such file or directory

# %%
import requests
from bs4 import BeautifulSoup
import csv

def scrape_wikiart_names(artist_url, author_name):
    url = f"https://www.wikiart.org/en/{artist_url}/all-works/text-list"
    response = requests.get(url)

    soup = BeautifulSoup(response.text, 'html.parser')
    paintings = soup.find_all('li', class_='painting-list-text-row')

    # Abrir el archivo en modo "agregar" ('a') para no sobrescribir los datos existentes
    with open('paintings.csv', mode='a', newline='') as file:
        writer = csv.writer(file)

        # Verificar si el archivo está vacío para escribir el encabezado solo una vez
        if file.tell() == 0:
            writer.writerow(["Author", "Painting Name", "URL"])  # Encabezados solo si el archivo está vacío

        for painting in paintings:
            painting_name = painting.find('a').text.strip()  # Obtener el nombre de la obra y quitar espacios en blanco
            img_page = painting.find('a')['href']
            writer.writerow([author_name, painting_name, f"https://www.wikiart.org{img_page}"])
            #print(f"Autor: {author_name}, Obra: {painting_name}")

# Ejemplo para obtener los datos de las obras de varios artistas
scrape_wikiart_names("vincent-van-gogh", "Vincent van Gogh")
scrape_wikiart_names("pablo-picasso", "Pablo Picasso")
scrape_wikiart_names("leonardo-da-vinci", "Leonardo da Vinci")
scrape_wikiart_names("claude-monet", "Claude Monet")
scrape_wikiart_names("salvador-dali", "Salvador Dali")

# %%
import os
import pandas as pd
import requests
from concurrent.futures import ThreadPoolExecutor
from bs4 import BeautifulSoup

# Lee el archivo CSV
df = pd.read_csv('paintings.csv')

# Crear la carpeta principal 'wikiart_images' si no existe
save_dir = 'wikiart_images'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Función para obtener la URL de la imagen
def get_image_url(page_url):
    try:
        response = requests.get(page_url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            img_tag = soup.find('img', itemprop='image')
            if img_tag and 'src' in img_tag.attrs:
                return img_tag['src'].replace(':large', '')
        else:
            print(f"Error al acceder a {page_url}: {response.status_code}")
    except Exception as e:
        print(f"Error al acceder a {page_url}: {e}")
    return None

# Función para descargar imágenes
def download_image(row):
    # Obtener el nombre del autor y de la obra
    author = row['Author'].replace(' ', '_').replace('/', '_')  # Limpiar el nombre del autor
    painting_name = row['Painting Name'].replace(' ', '_').replace('/', '_')  # Limpiar el nombre de la obra

    # Crear una carpeta para el autor dentro de 'wikiart_images'
    author_dir = os.path.join(save_dir, author)
    os.makedirs(author_dir, exist_ok=True)  # Esto asegura que no haya error si la carpeta ya existe (Sirve para un entorno con múltiple hilos)

    # Obtener la URL de la imagen
    image_url = get_image_url(row['URL'])
    if image_url:  # Verifica que la URL de la imagen no sea None
        # Generar el nombre del archivo usando el nombre de la obra
        image_name = f"{painting_name}.jpg"

        try:
            response = requests.get(image_url)
            if response.status_code == 200:
                # Guardar la imagen en la carpeta del autor
                with open(os.path.join(author_dir, image_name), 'wb') as f:
                    f.write(response.content)
                print(f"Descargada: {os.path.join(author_dir, image_name)}")
            else:
                print(f"Error al descargar {image_name}: {response.status_code}")
        except Exception as e:
            print(f"Error al descargar {image_name}: {e}")
    else:
        print(f"No se pudo obtener la URL de la imagen para {painting_name}")

# Descargar las imágenes usando múltiples hilos
with ThreadPoolExecutor(max_workers=10) as executor:  # max_workers determina cuántas descargas en paralelo
    # Pasar cada fila del DataFrame para la descarga
    futures = [executor.submit(download_image, row) for _, row in df.iterrows()]

    # Verificar la finalización de las tareas
    for future in futures:
        future.result()
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Descargada: wikiart_images/Vincent_van_Gogh/Two_Heads_of_Men.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Peasant_Woman,_Head.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/A_Pair_of_Shoes.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/A_Public_Garden_with_People_Walking_in_the_Rain.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/A_Square_in_Paris.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/A_View_of_Paris_with_the_Op.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Belvedere_Overlooking_Montmartre.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Basket_of_Carnations_and_Zinnias.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Coleus_Plant_in_a_Flowerpot.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Bowl_with_Peonies_and_Roses.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Female_Nude,_Seated.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Female_Nude,_Standing.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Female_Nude,_Seated.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Flying_Fox.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Flower_Pot_with_Asters.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Four_Sketches_of_a_Foot.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Geranium_in_a_Flowerpot.jpg
# No se pudo obtener la URL de la imagen para Figures_in_a_Park
# Descargada: wikiart_images/Vincent_van_Gogh/Glass_with_Roses.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Gypsum_Torso.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Guinguette.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Head_of_a_Man.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Head_of_a_Man.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Head_of_a_Man_with_Cap_(Lithographer's_Shade).jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Head_of_a_Man_with_Hat.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Head_of_a_Woman.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Head_of_a_Woman_with_Her_Hair_Loose.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Head_of_a_Woman.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Idol.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Idol.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Idol.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Idol.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Idol_and_Sketches_of_Venus.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Le_Moulin_de_la_Galette.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Idol.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Le_Moulin_de_la_Galette.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Le_Moulin_de_la_Galette_4.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Le_Moulin_de_la_Gallette_3.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Man,_Drawing_or_Writing.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Montmartre_the_Quarry_and__Windmills.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Montmartre_the_Quarry_and__Windmills.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Man_on_a_Bench.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/People_Walking_on_a_Street_in_the_Evening.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Moulin_de_la_Galette.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/People_Walking_in_Front_of_the_Palais_du_Luxembourg.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Park_with_Figures.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette_of_a_Female_Torso.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette_of_a_Female_Torso.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette_of_a_Kneeling_Man.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette_of_a_Female_Torso.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette_of_a_Horse.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette_of_a_Female_Torso.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette_of_a_Female_Torso.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Torso_of_a_Woman.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette_of_a_Male_Torso.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Statuette_of_a_Female_Torso.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Plaster_Torso_of_a_Woman,_Seen_from_the_Side.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Restaurant_Menu.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Seated_Female_Nude.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Seated_Male_Nude_Seen_from_the_Back.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Seated_Girl_and_Venus.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Seated_Girl_Seen_from_the_Front.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Seated_Man_with_a_Beard.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Seated_Man_with_a_Moustache_and_Cap.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Seated_Man_with_a_Beard.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Self-Portrait.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Self-Portrait_with_Cap.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Self-Portrait.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Self-Portrait_with_Dark_Felt_Hat.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Self-Portrait_with_Dark_Felt_Hat_at_the_Easel.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Self-Portrait_with_Pipe.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Self-Portrait_with_Pipe.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/
jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Vincent's_Bedroom_in_Arles.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Wheat_Field_with_Sheaves.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Vincent's_House.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Wheat_Field.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Vincent's_Bedroom.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Vincent's_Bedroom_in_Arles.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Vincent's_House_in_Arles_(The_Yellow_House).jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Wheat_Field_with_Setting_Sun.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Wheat_Field_with_Sheaves.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Wheat_Field.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Wheat_Field_with_Sheaves_and_Arles_in_the_Background.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Wheat_Field_with_Sheaves_and_Arles_in_the_Background.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Wheat_Field_with_the_Alpilles_Foothills_in_the_Background.jpg
# Descargada: wikiart_images/Vincent_van_Gogh/Zouave.jpg
# ...
# Descargada: wikiart_images/Salvador_Dali/Quantification_of_Leonardo_de_Vinci's_'Last_Supper'.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Second_Coming_of_Christ.jpg
# Descargada: wikiart_images/Salvador_Dali/Overture_in_Trompe_l'Oeil.jpg
# Descargada: wikiart_images/Salvador_Dali/Self-Portrait_(Photomontage_with_the_famous_'Mao-Marilyn'_that_Philippe_Halsman_created_at_Dali's_wish).jpg
# Descargada: wikiart_images/Salvador_Dali/Space_Eve.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Daughter_of_the_West_Wind.jpg
# Descargada: wikiart_images/Salvador_Dali/Trajan_on_Horseback.jpg
# Descargada: wikiart_images/Salvador_Dali/Hitler_Masturbating.jpg
# Descargada: wikiart_images/Salvador_Dali/Las_Galas_of_Port_Lligat.jpg
# Descargada: wikiart_images/Salvador_Dali/Gala's_Castle_at_Pubol.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Stereoscopic_Painting).jpg
# Descargada: wikiart_images/Salvador_Dali/Palace_of_the_Winds.jpg
# Descargada: wikiart_images/Salvador_Dali/Dali_from_the_Back_Painting_Gala_from_the_Back_Eternalized_by_Six_Virtual_Corneas_Provisionally_Reflected_in_Six_Real_Mirrors.jpg
# Descargada: wikiart_images/Salvador_Dali/portrait_of_Dr._Brian_Mercer.jpg
# Descargada: wikiart_images/Salvador_Dali/Portrait_of_Dr._Brian_Mercer.jpg
# Descargada: wikiart_images/Salvador_Dali/First_Cylindric_Crono-Hologram._Portrait_of_Alice_Cooper's_Brain.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Sleeping_Smoker.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Way_to_Pubol.jpg
# Descargada: wikiart_images/Salvador_Dali/Homage_To_Duchamp.jpg
# Descargada: wikiart_images/Salvador_Dali/Portrait_of_Eva_Suero_Talkish.jpg
# Descargada: wikiart_images/Salvador_Dali/Battle_in_the_Clouds.jpg
# Descargada: wikiart_images/Salvador_Dali/Armchair_with_Landscape_Painted_for_Gala's_Chateau_at_Pubol.jpg
# Descargada: wikiart_images/Salvador_Dali/Cranach_Metamorphosis_(Woman_in_a_Mirror).jpg
# Descargada: wikiart_images/Salvador_Dali/Gala's_Foot_(right_panel).jpg
# Descargada: wikiart_images/Salvador_Dali/Equestrian_Portrait_of_Carmen_Bordiu-Franco.jpg
# Descargada: wikiart_images/Salvador_Dali/Gala's_Foot_(left_panel).jpg
# Descargada: wikiart_images/Salvador_Dali/Allegory_of_Spring.jpg
# Descargada: wikiart_images/Salvador_Dali/Ampurdanese_Landscape,.jpg
# Descargada: wikiart_images/Salvador_Dali/Cybernetic_Odalisuqe-Homage_to_Bela_Julesz.jpg
# Descargada: wikiart_images/Salvador_Dali/Landscape_Near_Ampurdan.jpg
# Descargada: wikiart_images/Salvador_Dali/Pierrot_Lunaire.jpg
# Descargada: wikiart_images/Salvador_Dali/Woman_with_Egg_and_Arrows.jpg
# Descargada: wikiart_images/Salvador_Dali/Dawn,_Noon,_Sunset_and_Dusk.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Eye_of_the_Angelus.jpg
# Descargada: wikiart_images/Salvador_Dali/Long_Live_the_Station_at_Perpignan,_Long_Live_Figueras.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Harmony_of_the_Spheres.jpg
# Descargada: wikiart_images/Salvador_Dali/A_Soft_Watch_Put_in_the_Appropriate_Place_to_Cause_a_Young_Ephebe_to_Die_and_Be_Resuscitated_by_Excess_of_Satisfaction_(unfinished).jpg
# Descargada: wikiart_images/Salvador_Dali/Nude_and_Horse_with_Metamorphosis_(unfinished).jpg
# Descargada: wikiart_images/Salvador_Dali/Copy_of_a_Rubens_Copy_of_a_Leonardo.jpg
# Descargada: wikiart_images/Salvador_Dali/More_Beautiful_than_Canova.jpg
# Descargada: wikiart_images/Salvador_Dali/Pentagonal_Sardana.jpgDescargada: wikiart_images/Salvador_Dali/Pentagonal_Sardana.jpg
#
# Descargada: wikiart_images/Salvador_Dali/Phosphene.jpg
# Descargada: wikiart_images/Salvador_Dali/Raphaelesque_Hallucination.jpg
# Descargada: wikiart_images/Salvador_Dali/Searching_for_the_Fourth_Dimension.jpg
# Descargada: wikiart_images/Salvador_Dali/Study_for_'Compianto_Diabele'_by_Canova_(unfinished).jpg
# Descargada: wikiart_images/Salvador_Dali/Arabs.jpg
# Descargada: wikiart_images/Salvador_Dali/Three_Graces_of_Canova_(unfinished).jpg
# Descargada: wikiart_images/Salvador_Dali/Athens_Is_Burning!_The_School_of_Athens_and_the_Fire_in_the_Borgo.jpg
# Descargada: wikiart_images/Salvador_Dali/Athens_Is_Burning!_The_School_of_Athens_and_the_Fire_in_the_Borgo.jpg
# Descargada: wikiart_images/Salvador_Dali/Arabs.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Persistence_of_Memory.jpg
# Descargada: wikiart_images/Salvador_Dali/Sleeping_Young_Narcissus.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Prince_of_Sleep_(El_principe_de_ensueno).jpg
# Descargada: wikiart_images/Salvador_Dali/The_Cheerful_Horse.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Bridge_with_Reflections;_sketch_for_a_dual_image_picture,_unfinished).jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Landscape_with_Celestial_Beings).jpg
# Descargada: wikiart_images/Salvador_Dali/L'Etoile.jpg
# Descargada: wikiart_images/Salvador_Dali/Pink_Knot_and_Shell_on_the_Seashore.jpg
# Descargada: wikiart_images/Salvador_Dali/Amphitrite.jpg
# Descargada: wikiart_images/Salvador_Dali/Blue_Knot_and_Ear_of_Wheat_Next_to_the_Castle.jpg
# Descargada: wikiart_images/Salvador_Dali/Apparition_of_the_Visage_of_Aphrodite_of_Cnidos_in_a_Landscape.jpg
# Descargada: wikiart_images/Salvador_Dali/Figures_(Scene_after_Goya).jpg
# Descargada: wikiart_images/Salvador_Dali/Argus.jpg
# Descargada: wikiart_images/Salvador_Dali/Sybyle_Agripa.jpg
# Descargada: wikiart_images/Salvador_Dali/Hermes.jpg
# Descargada: wikiart_images/Salvador_Dali/Group_Surrounding_a_Reclining_Nude_-_Velazquez.jpg
# Descargada: wikiart_images/Salvador_Dali/Jason_Carrying_the_Golden_Fleece_(unfinished).jpg
# Descargada: wikiart_images/Salvador_Dali/Gala_in_a_Patio_Watching_the_Sky,_Where_the_Equestrian_Figure_of_Prince_Baltasar_Carlos_and_Several_Constellations_(All)_Appear,_after_Velazquez.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(The_Great_Masturbator_Appears_Behind_Arcades).jpg
# Descargada: wikiart_images/Salvador_Dali/Landscape_with_Rock_in_the_Shape_of_a_Triumphal_Arch.jpg
# Descargada: wikiart_images/Salvador_Dali/Mercury_and_Argus.jpg
# Descargada: wikiart_images/Salvador_Dali/Landscape.jpgDescargada: wikiart_images/Salvador_Dali/Medea_or_Jason_Taking_Possession_of_the_Golden_Fleece.jpg
#
# Descargada: wikiart_images/Salvador_Dali/The_Exterminating_Angels.jpg
# Descargada: wikiart_images/Salvador_Dali/Reading._Family_Scene_by_Lamplight.jpg
# Descargada: wikiart_images/Salvador_Dali/Ready-to-wear_Fashion_for_Next_Spring;_'Garlands,_Nests_and_Flowers'.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Looking_at_The_Great_Masturbator).jpgDescargada: wikiart_images/Salvador_Dali/Spanish_Nobleman_with_a_Cross_of_Brabant_on_His_Jerkin.jpg
#
# Descargada: wikiart_images/Salvador_Dali/The_Path_of_Enigmas_(first_version).jpg
# Descargada: wikiart_images/Salvador_Dali/The_Gaseous_Swan.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Garden_of_Hours.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Path_of_Enigmas_(second_version).jpg
# Descargada: wikiart_images/Salvador_Dali/The_Path_of_Enigma.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Pearl.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Tower_of_Enigmas.jpg
# Descargada: wikiart_images/Salvador_Dali/Three_Female_Figures_in_Festive_Gowns.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Head_of_a_Woman;_unfinished).jpg
# Descargada: wikiart_images/Salvador_Dali/The_Towers.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Imaginary_Landscape_at_Pubol).jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Skin_of_a_Beach).jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Female_Bust_with_Draped_Cloth).jpg
# Descargada: wikiart_images/Salvador_Dali/Tower.jpg
# Descargada: wikiart_images/Salvador_Dali/Tower.jpg
# Descargada: wikiart_images/Salvador_Dali/After_Michelangelo's_'Moses',_on_the_Tomb_of_Julius_II_in_Rome.jpg
# Descargada: wikiart_images/Salvador_Dali/Architectural_Contortion_of_El_Escorial.jpg
# Descargada: wikiart_images/Salvador_Dali/After_Michelangelo's_'Squatting_Child'.jpg
# Descargada: wikiart_images/Salvador_Dali/Atmospherocephalic_Figures.jpg
# Descargada: wikiart_images/Salvador_Dali/After_the_Head_of_'Giuliano_di_Medici.jpg
# Descargada: wikiart_images/Salvador_Dali/Classic_Figure_and_Head_(unfinished).jpgDescargada: wikiart_images/Salvador_Dali/Double_Victory_of_Gaudi.jpg
#
# No se pudo obtener la URL de la imagen para Woman_on_a_Ram
# Descargada: wikiart_images/Salvador_Dali/Don_Jose_Nieto_Velazquez_from_'Las_Meninas'_by_Velazquez.jpg
# Descargada: wikiart_images/Salvador_Dali/El_Escorial_and_Catastrophe-Form_Calligraphy.jpg
# Descargada: wikiart_images/Salvador_Dali/Enigma_(unfinished_version_of_'The_Three_Glorious_Enigmas_of_Gala').jpg
# Descargada: wikiart_images/Salvador_Dali/Exploded_Head.jpg
# Descargada: wikiart_images/Salvador_Dali/Figure_after_Michelangelo's_'Dawn'_on_the_Tomb_of_Lorenzo_di_Medici.jpg
# Descargada: wikiart_images/Salvador_Dali/Figure_in_the_Water_-_After_a_Drawing_by_Michelangelo_for_the_'Resurrection_of_Christ'.jpg
# Descargada: wikiart_images/Salvador_Dali/Giuliano_di_Medici'_by_Michelangelo,_Seen_from_Behind.jpg
# Descargada: wikiart_images/Salvador_Dali/Landscape_with_Hidden_Image_of_Michelangelo's_'David'.jpg
# Descargada: wikiart_images/Salvador_Dali/Figure_Inspired_by_the_Adam_of_the_Ceiling_of_the_Sistine_Chapel.jpg
# Descargada: wikiart_images/Salvador_Dali/Head,_after_Michelangelo's,_'Giuliano_di_Medici'.jpg
# Descargada: wikiart_images/Salvador_Dali/Mirror_Women_-_Mirror_Head.jpg
# Descargada: wikiart_images/Salvador_Dali/Othello_Dreaming_Venice.jpg
# Descargada: wikiart_images/Salvador_Dali/Rock_Figure_after_the_Head_of_Christ_in_the_'Pieta'_of_Palestrina_by_Michelangelo.jpg
# Descargada: wikiart_images/Salvador_Dali/Pieta.jpg
# Descargada: wikiart_images/Salvador_Dali/Saint_Sebastian.jpg
# Descargada: wikiart_images/Salvador_Dali/Scene_in_the_Courtyard_of_the_Escorial_with_a_Figure_in_the_Foreground_Inspired_by_Michelangelo's_'Evening'_on_the_Tomb_of_Lorenzo_di_Medici.jpg
# Descargada: wikiart_images/Salvador_Dali/Pieta.jpg
# Descargada: wikiart_images/Salvador_Dali/Sebastian_de_Morra_with_Catastrophic_Signs.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Infanta_Margarita_of_Velazquez_Appearing_in_the_Silhouette_of_Horsemen_in_the_Courtyard_of_the_Escorial.jpg
# Descargada: wikiart_images/Salvador_Dali/Ole.jpg
# Descargada: wikiart_images/Salvador_Dali/Study_for_'Ole'_(unfinished).jpg
# Descargada: wikiart_images/Salvador_Dali/The_Martyr.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Three_Glorious_Enigmas_of_Gala(second_version).jpg
# Descargada: wikiart_images/Salvador_Dali/Topological_Study_for_'Exploded_Head'.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Three_Glorious_Enigmas_of_Gala.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_-_Equestrian_Figure_of_Prince_Baltasar_Carlos,_after_Velazquez,_with_Figures_in_the_Courtyard_of_the_Escorial.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(After_'The_Night'_by_Michelangelo).jpg
# Descargada: wikiart_images/Salvador_Dali/Velazquez_and_a_Figure.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_-_Nude_Figures_after_Michelangelo.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(After_'The_Day'_by_Michelangelo).jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(first_study_for_'The_Three_Glorious_Enigmas_of_Gala').jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Composition_-_Courtyard_of_the_Escorial_with_Figure_and_Sebastian_De_Morra,_Veldzquez's_Dwarf).jpg
# Descargada: wikiart_images/Salvador_Dali/Velazquez_Dying_Behind_the_Window_on_the_Left_Side_Out_of_Which_a_Spoon_Projects.jpg
# Descargada: wikiart_images/Salvador_Dali/Warrior.jpg
# Descargada: wikiart_images/Salvador_Dali/Bed_and_Bedside_Table_Ferociously_Attacking_a_Cello.jpg
# Descargada: wikiart_images/Salvador_Dali/Bed_and_Two_Bedside_Tables_Ferociously_Attacking_a_Cello.jpg
# Descargada: wikiart_images/Salvador_Dali/Bed_and_Two_Bedside_Tables_Ferociously_Attacking_a_Cello.jpg
# Descargada: wikiart_images/Salvador_Dali/Bed_and_Two_Bedside_Tables_Ferociously_Attacking_a_Cello_(Final_Stage).jpg
# Descargada: wikiart_images/Salvador_Dali/Cutlet_and_Match_-_The_Chinese_Crab.jpg
# Descargada: wikiart_images/Salvador_Dali/Head_Inspired_by_Michelangelo.jpg
# Descargada: wikiart_images/Salvador_Dali/Bed,_Chair_and_Bedside_Table_Ferociously_Attacking_a_Cello.jpg
# Descargada: wikiart_images/Salvador_Dali/Pieta.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Swallow's_Tail.jpg
# Descargada: wikiart_images/Salvador_Dali/St._George_Overpowering_a_Cello.jpg
# Descargada: wikiart_images/Salvador_Dali/The_Truck_(We'll_be_arriving_later,_about_five_o'clock).jpg
# Descargada: wikiart_images/Salvador_Dali/Topological_Contortion_of_a_Female_Figure.jpg
# Descargada: wikiart_images/Salvador_Dali/Topological_Abduction_of_Europe_-_Homage_to_Rene_Thom.jpgDescargada: wikiart_images/Salvador_Dali/Topological_Contortion_of_a_Female_Figure_Becoming_a_Violoncello.jpg
#
# Descargada: wikiart_images/Salvador_Dali/Untitled_-_Head_of_a_Spanish_Nobleman,_Fashioned_by_the_Catastrophe_Model_from_a_Swallow's_Tail_and_Two_Halves_of_a_Cello.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_(Figures,_Pieta,_Catastrophic_Signs).jpg
# Descargada: wikiart_images/Salvador_Dali/Warrior_Mounted_on_an_Elephant_Overpowering_a_Cello.jpg
# Descargada: wikiart_images/Salvador_Dali/The_King's_Sword.jpg
# Descargada: wikiart_images/Salvador_Dali/Untitled_-_Series_on_Catastrophes.jpg
# Descargada: wikiart_images/Salvador_Dali/Nobility_of_Time.jpg
# Descargada: wikiart_images/Salvador_Dali/Profile_of_Time.jpg
# Descargada: wikiart_images/Salvador_Dali/Dance_of_Time_I.jpg

# %%
import numpy as np
import cv2
import os

def load_images_from_folder(folder):
    images = []
    labels = []
    # Recorrer todas las subcarpetas en el directorio principal
    for subfolder in os.listdir(folder):
        subfolder_path = os.path.join(folder, subfolder)
        if os.path.isdir(subfolder_path):  # Verificar que sea un directorio
            # Recorrer todas las imágenes en la subcarpeta
            for filename in os.listdir(subfolder_path):
                img_path = os.path.join(subfolder_path, filename)
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.resize(img, (299, 299))  # Redimensionar a 299x299 para InceptionV3
                    images.append(img)
                    labels.append(subfolder)  # Usar el nombre de la subcarpeta como etiqueta
    return images, labels

# Ejemplo de uso
images, labels = load_images_from_folder('wikiart_images')

print(f"Total de imágenes cargadas: {len(images)}")
print(f"Total de etiquetas cargadas: {len(labels)}")

print("Primeras etiquetas:", labels[:10])  # Mostrar las primeras 10 etiquetas para verificar
# Out:
# Total de imágenes cargadas: 4898
# Total de etiquetas cargadas: 4898
# Primeras etiquetas: ['Vincent_van_Gogh', 'Vincent_van_Gogh', 'Vincent_van_Gogh', 'Vincent_van_Gogh', 'Vincent_van_Gogh', 'Vincent_van_Gogh', 'Vincent_van_Gogh', 'Vincent_van_Gogh', 'Vincent_van_Gogh', 'Vincent_van_Gogh']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Crear un generador de datos con aumentación que simula condiciones típicas de fotos de celulares
datagen = ImageDataGenerator(
    rotation_range=15,          # Rotaciones pequeñas (0-15 grados)
    width_shift_range=0.1,      # Desplazamiento horizontal menor
    height_shift_range=0.1,     # Desplazamiento vertical menor
    zoom_range=0.1,             # Zoom aleatorio pequeño
    brightness_range=[0.8, 1.2],# Ajuste de brillo (más oscuro o más claro)
    horizontal_flip=True,       # Voltear horizontalmente
    rescale=1/255.0,            # Normalizar los píxeles
    fill_mode='nearest'         # Modo de relleno para áreas vacías
)

# Configurar el flujo de datos desde el directorio
train_generator = datagen.flow_from_directory(
    'wikiart_images',          # Directorio principal con subcarpetas de autores
    target_size=(224, 224),    # Tamaño de entrada esperado por MobileNetV2
    batch_size=32,             # Tamaño del batch
    class_mode='categorical',  # Clasificación multiclase
    shuffle=True               # Activar el shuffle
)
# Out:
# Found 4901 images belonging to 5 classes.

# %%
for batch in train_generator:
    print(f"Tamaño del lote: {len(batch[0])}")  # Verifica el tamaño de cada lote
    break

print(f"Total de imágenes en el generador: {train_generator.samples}")
print(f"Tamaño del batch: {train_generator.batch_size}")
print(f"Clases encontradas: {train_generator.class_indices}")

for batch_images, batch_labels in train_generator:
    print(f"Tamaño del lote: {len(batch_images)}")
    break  # Solo para mostrar un lote y no iterar indefinidamente
# Out:
# Tamaño del lote: 32
# Total de imágenes en el generador: 4901
# Tamaño del batch: 32
# Clases encontradas: {'Claude_Monet': 0, 'Leonardo_da_Vinci': 1, 'Pablo_Picasso': 2, 'Salvador_Dali': 3, 'Vincent_van_Gogh': 4}
# Tamaño del lote: 32

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# Crear el modelo base de MobileNetV2 (sin las capas superiores)
base_model = MobileNetV2(weights='imagenet', include_top=False)

# Añadir una capa de pooling global y una capa densa
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Reduce la dimensionalidad
x = Dense(512, activation='relu')(x)  # Capa densa con menos unidades
predictions = Dense(len(set(labels)), activation='softmax')(x)  # Capa de salida

# Definir el modelo final
model = Model(inputs=base_model.input, outputs=predictions)

# Congelar las capas del modelo base
for layer in base_model.layers:
    layer.trainable = False

# Compilar el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# <ipython-input-30-1e62bcc11731>:6: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Configurar el callback para reducir la tasa de aprendizaje
reduce_lr = ReduceLROnPlateau(
    monitor='loss',  # Puedes usar 'val_loss' si tienes un conjunto de validación
    factor=0.5,      # Factor por el cual la tasa de aprendizaje se reducirá
    patience=2,      # Número de épocas sin mejora antes de reducir la tasa
    min_lr=1e-6      # Límite inferior para la tasa de aprendizaje
)

# %%
# Entrenar el modelo utilizando el generador
model.fit(
    train_generator,
    epochs=5,
    steps_per_epoch=min(100, train_generator.samples // train_generator.batch_size), # Ajusta el número de pasos
    #steps_per_epoch = max(1, (train_generator.samples // train_generator.batch_size) - 1), #Por si la cantidad de img no es divisible entre el tamaño del batch
    #steps_per_epoch = train_generator.samples // train_generator.batch_size,
    callbacks=[reduce_lr]
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 181s 2s/step - accuracy: 0.6009 - loss: 1.0928 - learning_rate: 0.0010
# Epoch 2/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 84s 837ms/step - accuracy: 0.7864 - loss: 0.5914 - learning_rate: 0.0010
# Epoch 3/5
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.8070 - loss: 0.5385 - learning_rate: 0.0010
# Epoch 4/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 85s 844ms/step - accuracy: 0.8180 - loss: 0.4909 - learning_rate: 0.0010
# Epoch 5/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.8443 - loss: 0.4364 - learning_rate: 0.0010

# %%
# Ahora, hacer fine-tuning de las últimas capas convolucionales de InceptionV3
# Descongelar las últimas capas convolucionales (puedes experimentar con cuántas capas descongelar)
for layer in model.layers[:20]:
    layer.trainable = False
for layer in model.layers[20:]:
    layer.trainable = True

# Recompilar el modelo con un optimizador SGD de baja tasa de aprendizaje
from keras.optimizers import SGD
model.compile(optimizer=SGD(learning_rate=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',  # O 'loss' si no tienes un conjunto de validación
    patience=3,          # Número de épocas sin mejora antes de detener el entrenamiento
    restore_best_weights=True
)

# %%
# Entrenar nuevamente con las capas descongeladas
model.fit(
    train_generator,
    epochs=10,
    steps_per_epoch=min(100, train_generator.samples // train_generator.batch_size),
    #steps_per_epoch = max(1, (train_generator.samples // train_generator.batch_size) - 1),
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 468s 4s/step - accuracy: 0.6929 - loss: 0.8391 - learning_rate: 1.0000e-04
# Epoch 2/10
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss,learning_rate
#   current = self.get_monitor_value(logs)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 235s 2s/step - accuracy: 0.8214 - loss: 0.5094 - learning_rate: 1.0000e-04
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 503s 4s/step - accuracy: 0.8394 - loss: 0.4501 - learning_rate: 1.0000e-04
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 231s 2s/step - accuracy: 0.8323 - loss: 0.4811 - learning_rate: 1.0000e-04
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 447s 4s/step - accuracy: 0.8454 - loss: 0.4296 - learning_rate: 1.0000e-04
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.8592 - loss: 0.4021 - learning_rate: 1.0000e-04
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 449s 4s/step - accuracy: 0.8594 - loss: 0.4120 - learning_rate: 1.0000e-04
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.8613 - loss: 0.4009 - learning_rate: 1.0000e-04
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 449s 4s/step - accuracy: 0.8577 - loss: 0.3917 - learning_rate: 5.0000e-05
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 235s 2s/step - accuracy: 0.8713 - loss: 0.3825 - learning_rate: 5.0000e-05

# %%
import tensorflow as tf
import requests
from io import BytesIO
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

# Asumiendo que el modelo se llama 'model'
# URL de la imagen que quieres probar
url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTKN1Kkg-pWB7WQnM-1_ML22lGKN_FFbczAYw&s'

# Descargar la imagen desde la URL
response = requests.get(url)

# Verificar si la respuesta es una imagen
if 'image' in response.headers['Content-Type']:
    # Redimensionar a 224x224 para MobileNetV2
    img = load_img(BytesIO(response.content), target_size=(224, 224))
    img = img_to_array(img) / 255.0  # Normalización al rango [0, 1]
    img = np.expand_dims(img, axis=0)  # Añadir dimensión de batch

    # Hacer predicción con el modelo cargado
    predictions = model.predict(img)

    # Obtener la clase predicha
    predicted_class = np.argmax(predictions, axis=1)[0]

    # Invertir el mapeo class_indices para obtener el nombre del autor
    class_labels = {v: k for k, v in train_generator.class_indices.items()}

    # Mostrar la clase predicha (nombre del autor)
    predicted_label = class_labels[predicted_class]
    print(f"La clase predicha es: {predicted_label}")
else:
    print("La URL no apunta a una imagen válida.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# La clase predicha es: Claude_Monet

# %%
interpreter = tf.lite.Interpreter(model_path='modelo_entrenado_mejorado.tflite', experimental_delegates=[])
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print(f"Detalles de entrada: {input_details}")
print(f"Detalles de salida: {output_details}")
# Out:
# Detalles de entrada: [{'name': 'serving_default_keras_tensor_314:0', 'index': 0, 'shape': array([1, 1, 1, 3], dtype=int32), 'shape_signature': array([-1, -1, -1,  3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Detalles de salida: [{'name': 'StatefulPartitionedCall_1:0', 'index': 288, 'shape': array([1, 5], dtype=int32), 'shape_signature': array([-1,  5], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}